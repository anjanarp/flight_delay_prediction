# %%
# %pip install ipython jupyter
# %pip install dask[complete]
# %pip install pandas
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: dask[complete] in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (2024.5.2)
# Requirement already satisfied: click>=8.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (2024.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (23.2)
# Requirement already satisfied: partd>=1.2.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (0.12.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (0.6)
# Requirement already satisfied: lz4>=4.3.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (4.3.3)
# Requirement already satisfied: colorama in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from click>=8.1->dask[complete]) (0.4.6)
# Requirement already satisfied: locket in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from partd>=1.2.0->dask[complete]) (1.0.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from pyarrow>=7.0->dask[complete]) (1.26.4)
# Requirement already satisfied: pandas>=1.3 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (2.2.2)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (1.1.2)
# Requirement already satisfied: bokeh>=2.4.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (3.4.1)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (3.1.4)
# Requirement already satisfied: distributed==2024.5.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from dask[complete]) (2024.5.2)
# Requirement already satisfied: msgpack>=1.0.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from distributed==2024.5.2->dask[complete]) (1.0.8)
# Requirement already satisfied: psutil>=5.7.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from distributed==2024.5.2->dask[complete]) (5.9.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from distributed==2024.5.2->dask[complete]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from distributed==2024.5.2->dask[complete]) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from distributed==2024.5.2->dask[complete]) (6.3.3)
# Requirement already satisfied: urllib3>=1.24.3 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from distributed==2024.5.2->dask[complete]) (2.2.1)
# Requirement already satisfied: zict>=3.0.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from distributed==2024.5.2->dask[complete]) (3.0.0)
# Requirement already satisfied: contourpy>=1.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from bokeh>=2.4.2->dask[complete]) (1.2.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from bokeh>=2.4.2->dask[complete]) (10.3.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from bokeh>=2.4.2->dask[complete]) (2024.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jinja2>=2.10.3->dask[complete]) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from pandas>=1.3->dask[complete]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from pandas>=1.3->dask[complete]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from pandas>=1.3->dask[complete]) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3->dask[complete]) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipython in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (8.20.0)
# Requirement already satisfied: jupyter in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (1.0.0)
# Requirement already satisfied: decorator in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipython) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipython) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipython) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipython) (5.7.1)
# Requirement already satisfied: colorama in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: notebook in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter) (7.0.8)
# Requirement already satisfied: qtconsole in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter) (5.5.2)
# Requirement already satisfied: jupyter-console in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter) (7.10.0)
# Requirement already satisfied: ipykernel in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter) (6.28.0)
# Requirement already satisfied: ipywidgets in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter) (8.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipykernel->jupyter) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipykernel->jupyter) (5.5.0)
# Requirement already satisfied: nest-asyncio in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipykernel->jupyter) (23.2)
# Requirement already satisfied: psutil in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipykernel->jupyter) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipykernel->jupyter) (6.3.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipywidgets->jupyter) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from ipywidgets->jupyter) (3.0.11)
# Requirement already satisfied: beautifulsoup4 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbconvert->jupyter) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbconvert->jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbconvert->jupyter) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbconvert->jupyter) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from notebook->jupyter) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from notebook->jupyter) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from notebook->jupyter) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from notebook->jupyter) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: executing in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from stack-data->ipython) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from stack-data->ipython) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.4.4)
# Requirement already satisfied: overrides in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.32.2)
# Requirement already satisfied: fastjsonschema in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.16.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2024.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2024.2.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: fqdn in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.4)
# Requirement already satisfied: uri-template in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.9.0.20240316)
# Requirement already satisfied: pandas in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\raaja\anaconda3\envs\anjana_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dask.dataframe as dd
import os
from IPython.display import display
import json
import pandas as pd
import numpy as np

# %%
# directory paths to the folders that hold the 2016 and 2017 flight data
flight_data_dir_2016 = r"C:\Users\raaja\OneDrive\Documents\maichu development\ml project #1\2016\2016_DATA"
flight_data_dir_2017 = r"C:\Users\raaja\OneDrive\Documents\maichu development\ml project #1\2017\2017_DATA"

# %%
# a function to extract information given a data directory path as an argument
def load_flight_data(data_dir):
    # initialize an empty Dask dataframe
    combined_df = None

    # iterate throughe each file in the given directory path
    for file in os.listdir(data_dir):
        # read into the file if it is a csv file
        if file.endswith('.csv'):
            # create the full filepath for that file given the filename
            file_path = os.path.join(data_dir, file)

            # based off of debugging messages, set dtype as python interpreter cannot predict the types of the columns if they are mixed
            df = dd.read_csv(file_path, dtype={'ArrTime': 'float64',
       'ArrivalDelayGroups': 'float64',
       'CancellationCode': 'object',
       'DepTime': 'float64',
       'DepartureDelayGroups': 'float64',
       'Div1Airport': 'object',
       'Div1TailNum': 'object',
       'Div2Airport': 'object',
       'Div2TailNum': 'object',
       'Div3Airport': 'object',
       'WheelsOff': 'float64',
       'WheelsOn': 'float64',
       'DivAirportLandings': 'float64'})
            
            # actually set the data frame as a Dask data frame here appropriately
            if combined_df is None:
                combined_df = df
            else:
                combined_df = dd.concat([combined_df, df])

    return combined_df

# %%
# call the above function on 2016 and 2017 directory paths and assign them to a data frame each
flight_data_2016 = load_flight_data(flight_data_dir_2016)
flight_data_2017 = load_flight_data(flight_data_dir_2017)

# %%
# merge both years data frames into a single Dask data frame
flight_data = dd.concat([flight_data_2016, flight_data_2017], ignore_index=True)

# %%
# make a list of the desired columns in the data frame
desired_columns = ["FlightDate", "Quarter", "Year", "Month", "DayofMonth",
                  "DepTime", "DepDel15", "CRSDepTime", "DepDelayMinutes", "Origin", "Dest",
                  "OriginAirportID", "DestAirportID", "ArrTime", "CRSArrTime",
                  "ArrDel15", "ArrDelayMinutes"]

# %%
# make a new data frame with only the filtered columns by dropping the unrequired columns
filtered_flight_data = flight_data.drop(columns=list(set(flight_data.columns) - set(desired_columns)))

# %%
# compute the Dask data frame into a Pandas data frame (note: computationally expensive)
dataf = filtered_flight_data.compute()
# Out:
#         Year  Quarter  Month  DayofMonth  FlightDate  OriginAirportID Origin  \
# 0       2016        1      1           6  2016-01-06            11298    DFW
# 1       2016        1      1           7  2016-01-07            11298    DFW
# 2       2016        1      1           8  2016-01-08            11298    DFW
# 3       2016        1      1           9  2016-01-09            11298    DFW
# 4       2016        1      1          10  2016-01-10            11298    DFW
# ...      ...      ...    ...         ...         ...              ...    ...
# 153329  2017        3      9          25  2017-09-25            13930    ORD
# 153330  2017        3      9          25  2017-09-25            12478    JFK
# 153331  2017        3      9          25  2017-09-25            12451    JAX
# 153332  2017        3      9          25  2017-09-25            11697    FLL
# 153333  2017        3      9          25  2017-09-25            14027    PBI
#
#         DestAirportID Dest  CRSDepTime  DepTime  DepDelayMinutes  DepDel15  \
# 0               11433  DTW        1100   1057.0              0.0       0.0
# 1               11433  DTW        1100   1056.0              0.0       0.0
# 2               11433  DTW        1100   1055.0              0.0       0.0
# 3               11433  DTW        1100   1102.0              2.0       0.0
# 4               11433  DTW        1100   1240.0            100.0       1.0
# ...               ...  ...         ...      ...              ...       ...
# 153329          10721  BOS        1018   1332.0            194.0       1.0
# 153330          12954  LGB        1828   1822.0              0.0       0.0
# 153331          11697  FLL         630    623.0              0.0       0.0
# 153332          12451  JAX         700    654.0              0.0       0.0
# 153333          10721  BOS        1001    952.0              0.0       0.0
#
#         CRSArrTime  ArrTime  ArrDelayMinutes  ArrDel15
# 0             1438   1432.0              0.0       0.0
# 1             1438   1426.0              0.0       0.0
# 2             1438   1445.0              7.0       0.0
# 3             1438   1433.0              0.0       0.0
# 4             1438   1631.0            113.0       1.0
# ...            ...      ...              ...       ...
# 153329        1335   1647.0            192.0       1.0
# 153330        2135   2135.0              0.0       0.0
# 153331         743    732.0              0.0       0.0
# 153332         812    802.0              0.0       0.0
# 153333        1301   1247.0              0.0       0.0
#
# [11292279 rows x 17 columns]

# %%
# a list of all the airports we are interested in
desired_airports = ["ATL", "CLT", "DEN", "DFW", "EWR",
                    "IAH", "JFK", "LAS", "LAX", "MCO",
                    "MIA", "ORD", "PHX", "SEA", "SFO"]

# a list of all the years within each airport directory we are interested in holding the data of
desired_years = [2016, 2017]

# %%
# a directory path to a folder with all the airport folders 
airports_dir_path = r"C:\Users\raaja\OneDrive\Documents\maichu development\ml project #1\weather"

# %%
# initialize an empty data frame
weather_data_df = pd.DataFrame()

# %%
# os.listdir returns a list of every single file and airport in a filepath, which this for loop would iterate through
for airport in os.listdir(airports_dir_path):
    # if the filename returned by os.listdir is an airport that is in the desired_columns list...
    if airport in desired_airports:
        # generate a full file path to that folder to iterate through
        full_airport_path = os.path.join(airports_dir_path, airport)

        # for each file in eaach airport folder ...
        for filename in os.listdir(full_airport_path):

            # if that file contains one of the years that we are interested in for the model...
            if any(str(year) in filename for year in desired_years):
                # generate a full filepath to that file to read into
                file_path = os.path.join(full_airport_path, filename)

                # create airport column based on folder name
                airport_name = airport

                # syntax to read into a json file given a file_path
                with open(file_path, 'r') as f:
                    data = json.load(f)

                    # since weather is given as a list, we can iterate through it to find the columns we want
                    for daily_weather in data['data']['weather']:

                        # extract date from "weather" column
                        date = daily_weather['date']

                        # create a data structure to hold the  columns from "hourly" data
                        hourly_data = daily_weather['hourly']

                        # create a DataFrame from hourly data
                        hourly_df = pd.DataFrame(hourly_data)

                        # select the desired columns
                        hourly_df = hourly_df[["windspeedKmph", "winddirDegree", "weatherCode", "precipMM",
                                               "visibility", "pressure", "cloudcover", "DewPointF",
                                               "WindGustKmph", "tempF", "WindChillF", "humidity", "time"]]

                        # add the airport and date columns
                        hourly_df["airport"] = airport_name
                        hourly_df["date"] = date

                        # Concatenate with existing data
                        weather_data_df = pd.concat([weather_data_df, hourly_df], ignore_index=True)

# %%
# Out:
#        windspeedKmph winddirDegree weatherCode precipMM visibility pressure  \
# 0                 11           318         176      0.1         10     1023
# 1                 13           317         176      0.0         10     1023
# 2                 14           315         122      0.0         10     1023
# 3                 16           314         122      0.0         10     1023
# 4                 17           314         122      0.0         10     1023
# ...              ...           ...         ...      ...        ...      ...
# 263155            26           296         113      0.0         10     1014
# 263156            26           298         113      0.0         10     1014
# 263157            26           300         113      0.0         10     1014
# 263158            23           302         113      0.0         10     1014
# 263159            20           303         113      0.0         10     1014
#
#        cloudcover DewPointF WindGustKmph tempF WindChillF humidity  time  \
# 0             100        47           17    49         46       91     0
# 1             100        44           22    46         42       92   100
# 2             100        41           26    43         38       92   200
# 3             100        38           30    40         33       93   300
# 4             100        38           30    40         33       93   400
# ...           ...       ...          ...   ...        ...      ...   ...
# 263155          0        57           27    67         67       70  1900
# 263156          0        58           27    67         67       71  2000
# 263157          0        58           27    67         67       73  2100
# 263158          0        58           25    66         66       74  2200
# 263159          0        58           22    66         66       75  2300
#
#        airport        date
# 0          ATL  2016-01-01
# 1          ATL  2016-01-01
# 2          ATL  2016-01-01
# 3          ATL  2016-01-01
# 4          ATL  2016-01-01
# ...        ...         ...
# 263155     SFO  2017-09-30
# 263156     SFO  2017-09-30
# 263157     SFO  2017-09-30
# 263158     SFO  2017-09-30
# 263159     SFO  2017-09-30
#
# [263160 rows x 15 columns]

# %%
# a function that rounds a military time to the closest hour
def roundoff(time):
    hour = time // 100
    minute = time % 100
    if (minute > 30):
        hour += 1

    hour = (hour % 24) * 100
    return hour

# print(roundoff(2259))

# %%
# drop all the nul values in the flight data frame
dataf.dropna(inplace=True)

# %%
# round the CRS departure time to the closest hour to correspond with the most accurate weather data
dataf["roundDepTime"] = dataf["CRSDepTime"].apply(roundoff)
# dataf["roundArrTime"] = dataf["CRSArrTime"].apply(roundoff)

# %%
# drop all the rows where the origin airport and the destination airport is not an airport in desired airports
dataf = dataf[dataf["Origin"].isin(desired_airports) & dataf["Dest"].isin(desired_airports)]

# if you are making a training model only based off of the origin airports weather then there is no need to drop any destination airports that we do not have weather data on
# dataf= dataf[dataf["Origin"].isin(desired_airports)]
# dataf = dataf.drop(columns=list(set(["roundArrTime"])))

# %%
# define columns to typecast
int_cols = weather_data_df.columns.drop(['airport', 'date'])

# try converting to integer, handle errors with 'coerce'
try:
  weather_data_df[int_cols] = weather_data_df[int_cols].apply(pd.to_numeric, errors='coerce')
  print("Successfully converted convertible columns to int64!")
  print(weather_data_df.dtypes)
except:
  print("Error: Some columns might not be convertible to int64.")

# check data types after conversion
# print(weather_data_df.dtypes)
# Out:
# Successfully converted convertible columns to int64!
# windspeedKmph      int64
# winddirDegree      int64
# weatherCode        int64
# precipMM         float64
# visibility         int64
# pressure           int64
# cloudcover         int64
# DewPointF          int64
# WindGustKmph       int64
# tempF              int64
# WindChillF         int64
# humidity           int64
# time               int64
# airport           object
# date              object
# dtype: object

# %%
# merge the flight and the weather data set based on the date, time, and airport
merged_df = pd.merge(dataf, weather_data_df, how='left', left_on=['FlightDate', 'roundDepTime', 'Origin'], right_on=['date', 'time', 'airport'])

# %%
# save the merged dataframe to a csv file
merged_df.to_csv(r'merged_data.csv', index=False)

# %%
# Assuming your DataFrame is named 'merged_df'
merged_df['IsDelayed'] = merged_df['ArrDelayMinutes'].gt(0).map({True: "Delayed", False: "Not Delayed"})
# Out:
#          Year  Quarter  Month  DayofMonth  FlightDate  OriginAirportID Origin  \
# 0        2016        1      1           1  2016-01-01            14747    SEA
# 1        2016        1      1           2  2016-01-02            14747    SEA
# 2        2016        1      1           3  2016-01-03            14747    SEA
# 3        2016        1      1           4  2016-01-04            14747    SEA
# 4        2016        1      1           5  2016-01-05            14747    SEA
# ...       ...      ...    ...         ...         ...              ...    ...
# 1851431  2017        3      9          25  2017-09-25            14771    SFO
# 1851432  2017        3      9          25  2017-09-25            11618    EWR
# 1851433  2017        3      9          25  2017-09-25            13204    MCO
# 1851434  2017        3      9          25  2017-09-25            12889    LAS
# 1851435  2017        3      9          25  2017-09-25            13204    MCO
#
#          DestAirportID Dest  CRSDepTime  ...  cloudcover  DewPointF  \
# 0                12478  JFK         745  ...           0         23
# 1                12478  JFK         745  ...           0         25
# 2                12478  JFK         745  ...           0         20
# 3                12478  JFK         745  ...          93         33
# 4                12478  JFK         710  ...         100         35
# ...                ...  ...         ...  ...         ...        ...
# 1851431          12478  JFK        2045  ...           0         63
# 1851432          13204  MCO        1205  ...           8         68
# 1851433          11618  EWR        1141  ...          17         74
# 1851434          12478  JFK        2159  ...           1         27
# 1851435          12478  JFK         605  ...          25         73
#
#          WindGustKmph  tempF  WindChillF  humidity  time  airport        date  \
# 0                   8     34          29        65   800      SEA  2016-01-01
# 1                   8     37          33        63   800      SEA  2016-01-02
# 2                   7     32          28        64   800      SEA  2016-01-03
# 3                   8     35          31        94   800      SEA  2016-01-04
# 4                  10     38          35        91   700      SEA  2016-01-05
# ...               ...    ...         ...       ...   ...      ...         ...
# 1851431            20     72          72        72  2100      SFO  2017-09-25
# 1851432             8     83          83        60  1200      EWR  2017-09-25
# 1851433            10     84          84        71  1200      MCO  2017-09-25
# 1851434            19     64          64        24  2200      LAS  2017-09-25
# 1851435             8     76          76        92   600      MCO  2017-09-25
#
#            IsDelayed
# 0            Delayed
# 1            Delayed
# 2        Not Delayed
# 3        Not Delayed
# 4        Not Delayed
# ...              ...
# 1851431  Not Delayed
# 1851432  Not Delayed
# 1851433  Not Delayed
# 1851434  Not Delayed
# 1851435  Not Delayed
#
# [1851436 rows x 34 columns]

# %%
# save the merged dataframe to a csv file
merged_df.to_csv(r'merged_data2.csv', index=False)
